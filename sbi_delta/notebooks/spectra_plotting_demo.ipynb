# %% [markdown]
# # SpectraManager Plotting Demo
#
# This notebook demonstrates how to use the `SpectraManager` along with the
# plotting utilities in `sbi_delta.spectra.plotting`.

# %%
import os
import sys
base_path = os.path.abspath("../..")
print(f"Adding base path: {base_path}")
sys.path.append(base_path)  # Adjust path as needed
from sbi_delta.config import BaseConfig
from sbi_delta.spectra_manager import SpectraManager
# Out:
# Adding base path: /groups/spruston/home/moharb/sbi-DELTA

# %%
# Initialize with your data folder and dye names
spectra = os.path.join(base_path, 'data', 'spectra_npz')
cfg = BaseConfig(min_wavelength=400.0, max_wavelength=800.0, wavelength_step=1.0)
mgr = SpectraManager(cfg, spectra, ['AF488', 'AF647'])
mgr.load()
print(mgr)
# Out:
# INFO:sbi_delta.spectra_manager:Initialized SpectraManager(folder=/groups/spruston/home/moharb/sbi-DELTA/data/spectra_npz, dyes=['AF488', 'AF647'])
# INFO:sbi_delta.spectra_manager:Starting load() of spectra
# INFO:sbi_delta.spectra_manager:Found 20 .npz files in '/groups/spruston/home/moharb/sbi-DELTA/data/spectra_npz'
# INFO:sbi_delta.spectra_manager:Loading emission spectrum for dye 'AF488' from /groups/spruston/home/moharb/sbi-DELTA/data/spectra_npz/AF488.npz
# INFO:sbi_delta.spectra_manager:Completed processing for 'AF488'
# INFO:sbi_delta.spectra_manager:Loading emission spectrum for dye 'AF647' from /groups/spruston/home/moharb/sbi-DELTA/data/spectra_npz/AF647.npz
# INFO:sbi_delta.spectra_manager:Completed processing for 'AF647'
# INFO:sbi_delta.spectra_manager:Loading excitation spectrum for dye 'AF488' from /groups/spruston/home/moharb/sbi-DELTA/data/spectra_npz/AF488.npz
# INFO:sbi_delta.spectra_manager:Completed processing for 'AF488'
# INFO:sbi_delta.spectra_manager:Loading excitation spectrum for dye 'AF647' from /groups/spruston/home/moharb/sbi-DELTA/data/spectra_npz/AF647.npz
# INFO:sbi_delta.spectra_manager:Completed processing for 'AF647'
# INFO:sbi_delta.spectra_manager:Completed load(): 2 emission dyes, 2 excitation dyes
# <SpectraManager(folder=PosixPath('/groups/spruston/home/moharb/sbi-DELTA/data/spectra_npz'), dyes=['AF488', 'AF647'])
#  Emission loaded: ['AF488', 'AF647']
#  Excitation loaded: ['AF488', 'AF647']>

# %%
# Plot a single emission spectrum
ax = mgr.plot_emission('AF488')
ax.figure.show()

# %%
# Plot all emission spectra
ax =  mgr.plot_all_emissions()
ax.figure.show()

# %%
# Plot a single excitation spectrum
ax = mgr.plot_excitation('AF647')
ax.figure.show()

# %%
# Plot all excitation spectra
ax = mgr.plot_all_excitations()
ax.figure.show()

# %%
ax = mgr.plot_all_spectra();
